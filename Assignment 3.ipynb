# %%
#Descriptive Analytics for Numerical Columns

# %%
#●	Objective: To compute and analyze basic statistical measures for numerical columns in the dataset

# %%
#	Load the dataset into a data analysis tool or programming environment (e.g., Python with pandas library).

# %%
import pandas as pd

# %%
df=pd.read_csv("sales_data_with_discounts.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
#Identify numerical columns in the dataset.

# %%
df.columns[[4,8,9,10,11,12]]
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
df[df.columns[[4,8,9,10,11,12]]]
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# ...

# %%
#	Calculate the mean, median, mode, and standard deviation for these columns.

# %%
df['Volume'].mean()
# Out:
# np.float64(5.066666666666666)

# %%
df['Volume'].median()
# Out:
# 4.0

# %%
df['Volume'].mode()
# Out:
# 0    3
# Name: Volume, dtype: int64

# %%
df['Volume'].std()
# Out:
# 4.231602391213926

# %%
df['Avg Price'].mean()
# Out:
# np.float64(10453.433333333332)

# %%
df['Avg Price'].median()
# Out:
# 1450.0

# %%
df['Avg Price'].mode()
# Out:
# 0     400
# 1     450
# 2     500
# 3    1300
# 4    8100
# Name: Avg Price, dtype: int64

# %%
df['Avg Price'].std()
# Out:
# 18079.90483993645

# %%
df['Total Sales Value'].mean()
# Out:
# np.float64(33812.83555555555)

# %%
df['Total Sales Value'].median()
# Out:
# 5700.0

# %%
df['Total Sales Value'].mode()
# Out:
# 0    24300
# Name: Total Sales Value, dtype: int64

# %%
df['Total Sales Value'].std()
# Out:
# 50535.07417255328

# %%
df['Discount Rate (%)'].mean()
# Out:
# np.float64(15.155241895330914)

# %%
df['Discount Rate (%)'].median()
# Out:
# 16.57776564929597

# %%
df['Discount Rate (%)'].mode()
# Out:
# 0       5.007822
# 1       5.055218
# 2       5.059801
# 3       5.072124
# 4       5.084108
#          ...
# 445    19.940610
# 446    19.965340
# 447    19.976879
# 448    19.982257
# 449    19.992407
# Name: Discount Rate (%), Length: 450, dtype: float64

# %%
df['Discount Rate (%)'].std()
# Out:
# 4.220602153325511

# %%
df['Discount Amount'].mean()
# Out:
# np.float64(3346.499424342415)

# %%
df['Discount Amount'].median()
# Out:
# 988.9337332382784

# %%
df['Discount Amount'].mode()
# Out:
# 0         69.177942
# 1         73.025199
# 2         93.649161
# 3         94.682735
# 4        102.705757
#            ...
# 445    17900.983733
# 446    21153.498820
# 447    21496.675367
# 448    25328.224204
# 449    25738.022194
# Name: Discount Amount, Length: 450, dtype: float64

# %%
df['Discount Amount'].std()
# Out:
# 4509.9029633539985

# %%
df['Net Sales Value'].mean()
# Out:
# np.float64(30466.336131270138)

# %%
df['Net Sales Value'].median()
# Out:
# 4677.788059301853

# %%
df['Net Sales Value'].mode()
# Out:
# 0         326.974801
# 1         330.822058
# 2         466.350839
# 3         485.317265
# 4         496.607104
#            ...
# 445    162603.186379
# 446    163915.971000
# 447    163967.080070
# 448    166263.161348
# 449    179507.479049
# Name: Net Sales Value, Length: 450, dtype: float64

# %%
df['Net Sales Value'].std()
# Out:
# 46358.656624066934

# %%
#Data Visualization

# %%
#●	Objective: To visualize the distribution and relationship of numerical and categorical variables in the dataset.

# %%
#●	Histograms:
#	plot histograms for each numerical column.
#	Analyze the distribution (e.g., skewness, presence of outliers) and provide inferences.

# %%
df['Volume'].hist()
# Out:
# <Axes: >

# %%
# above histogram shows postive skewness and has ouliers which are far away from value18

# %%
df['Avg Price'].hist()
# Out:
# <Axes: >

# %%
#above histogram also shows postive skewness and has ouliers far away from 24000

# %%
df['Total Sales Value'].hist()
# Out:
# <Axes: >

# %%
# above histogram shows positive skewness,here the pickedness is mostly from 0 to 19000 and remaining values are plotted less among other values

# %%
df['Discount Rate (%)'].hist()
# Out:
# <Axes: >

# %%
#The above histogram shows negative skewness and there are ouliers

# %%
df['Discount Amount'].hist()
# Out:
# <Axes: >

# %%
#The above histogram shows positive skewness and has outliers

# %%
df['Net Sales Value'].hist()
# Out:
# <Axes: >

# %%
#The above histogram shows positive skewness and here the pickedness at mostly from 0 to 19000 and remaining values are plotted less among other values

# %%
#●	Box Plots:
#	Create boxplots for numerical variables to identify outliers and the interquartile range.
#Discuss any findings, such as extreme values or unusual distributions.

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df['Volume'],vert=False)
plt.show()

# %%
df['Volume'].describe()
# Out:
# count    450.000000
# mean       5.066667
# std        4.231602
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        6.000000
# max       31.000000
# Name: Volume, dtype: float64

# %%
q1=3
q2=4
q3=6

# %%
IQR= q3-q1

# %%
IQR
# Out:
# 3

# %%
Upper_Whisker_Length=q3+(1.5*IQR)

# %%
Upper_Whisker_Length
# Out:
# 10.5

# %%
len(df[df['Volume']> Upper_Whisker_Length])
# Out:
# 44

# %%
#In Volume, there are 44 outliers and interquartile range is 3,having left skewness

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df['Avg Price'],vert=False)
plt.show()

# %%
df['Avg Price'].describe()
# Out:
# count      450.000000
# mean     10453.433333
# std      18079.904840
# min        290.000000
# 25%        465.000000
# 50%       1450.000000
# 75%      10100.000000
# max      60100.000000
# Name: Avg Price, dtype: float64

# %%
q1=465
q2=1450
q3=10100

# %%
IQR= q3-q1
IQR
# Out:
# 9635

# %%
Upper_Whisker_Length=q3+(1.5*IQR) 
Upper_Whisker_Length
# Out:
# 24552.5

# %%
len(df[df['Avg Price']> Upper_Whisker_Length])
# Out:
# 60

# %%
#In Avg Price , there are 60 outliers and interquartile range is 9635,having left skewness

# %%
plt.boxplot(df['Total Sales Value'],vert=False)
plt.show()

# %%
df['Total Sales Value'].describe()
# Out:
# count       450.000000
# mean      33812.835556
# std       50535.074173
# min         400.000000
# 25%        2700.000000
# 50%        5700.000000
# 75%       53200.000000
# max      196400.000000
# Name: Total Sales Value, dtype: float64

# %%
q1=2700
q2=5700
q3=53200

# %%
IQR= q3-q1
IQR
# Out:
# 50500

# %%
Upper_Whisker_Length=q3+(1.5*IQR) 
Upper_Whisker_Length
# Out:
# 128950.0

# %%
len(df[df['Total Sales Value']> Upper_Whisker_Length])
# Out:
# 36

# %%
#In Total Sales Value , there are 130 outliers and interquartile range is 9635,having left skewness

# %%
plt.boxplot(df['Discount Rate (%)'],vert=False)
plt.show()

# %%
df['Discount Rate (%)'].describe()
# Out:
# count    450.000000
# mean      15.155242
# std        4.220602
# min        5.007822
# 25%       13.965063
# 50%       16.577766
# 75%       18.114718
# max       19.992407
# Name: Discount Rate (%), dtype: float64

# %%
q1=14
q2=16
q3=18

# %%
IQR= q3-q1
IQR
# Out:
# 4

# %%
Lower_Whisker_Length=q1-(1.5*IQR) 
Lower_Whisker_Length
# Out:
# 8.0

# %%
len(df[df['Discount Rate (%)']<Lower_Whisker_Length])
# Out:
# 51

# %%
#In Discount Rate (%) , there are 51 outliers and interquartile range is 4,having right skewness

# %%
plt.boxplot(df['Discount Amount'],vert=False)
plt.show()

# %%
df['Discount Amount'].describe()
# Out:
# count      450.000000
# mean      3346.499424
# std       4509.902963
# min         69.177942
# 25%        460.459304
# 50%        988.933733
# 75%       5316.495427
# max      25738.022194
# Name: Discount Amount, dtype: float64

# %%
q1=460
q2=989
q3=5316

# %%
IQR= q3-q1
IQR
# Out:
# 4856

# %%
Upper_Whisker_Length=q3+(1.5*IQR) 
Upper_Whisker_Length
# Out:
# 12600.0

# %%
len(df[df['Discount Amount']>Upper_Whisker_Length])
# Out:
# 24

# %%
#In Discount Amount, there are 24 outliers and interquartile range is 4856,having left skewness

# %%
plt.boxplot(df['Net Sales Value'],vert=False)
plt.show()

# %%
df['Net Sales Value'].describe()
# Out:
# count       450.000000
# mean      30466.336131
# std       46358.656624
# min         326.974801
# 25%        2202.208645
# 50%        4677.788059
# 75%       47847.912852
# max      179507.479049
# Name: Net Sales Value, dtype: float64

# %%
q1=2202
q2=4677
q3=47848

# %%
IQR= q3-q1
IQR
# Out:
# 45646

# %%
Upper_Whisker_Length=q3+(1.5*IQR) 
Upper_Whisker_Length
# Out:
# 116317.0

# %%
len(df[df['Net Sales Value']>Upper_Whisker_Length])
# Out:
# 35

# %%
#In Discount Amount, there are 35 outliers and interquartile range is 45646,having left skewness

# %%
#●	Bar Chart Analysis for Categorical Column:
	#Identify categorical columns in the dataset.
	#Create bar charts to visualize the frequency or count of each category.
	#Analyze the distribution of categories and provide insights.

# %%
Categorial_columns= df[df.columns[[0,1,2,3,5,6,7]]]

# %%
Categorial_columns
# Out:
#            Date       Day  SKU City         BU  Brand       Model
# 0    01-04-2021  Thursday  M01    C    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C  Lifestyle  Jeera     M-Shoes
#
# [450 rows x 7 columns]

# %%
df['Volume'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Volume'>

# %%
# The bar height represents the number of counts,in volume the graph is gradually reducing the value

# %%
df['Avg Price'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Avg Price'>

# %%
#In Avg Price, the graph is mostly having same values

# %%
df['Total Sales Value'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Total Sales Value'>

# %%
#In Total Sales Value , the pick is less but the values are gradually decreasing

# %%
df['Discount Rate (%)'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Discount Rate (%)'>

# %%
#In Discount Rate (%), the values are equally distributed

# %%
df['Discount Amount'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Discount Amount'>

# %%
#In Discount Amount, the values are equally distributed

# %%
df['Net Sales Value'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Net Sales Value'>

# %%
#In Net Sales Value,the values are equally distributed
