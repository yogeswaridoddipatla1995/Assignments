# %%
#EXPLORATORY DATA ANALYSIS ON A DATASET

# %%
#Objective:
#The main goal of this assignment is to conduct a thorough exploratory analysis of the "cardiographic.csv" dataset to uncover insights, identify patterns, and understand the dataset's underlying structure. You will use statistical summaries, visualizations, and data manipulation techniques to explore the dataset comprehensively.

# %%
#Tasks:

# %%
#1.	Data Cleaning and Preparation:

# %%
#●	Load the dataset into a data frame or equivalent data structure.

# %%
import pandas as pd

# %%
df= pd.read_csv("Cardiotocographic.csv")

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
#●	Handle missing values appropriately (e.g., imputation, deletion).

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
mean_of_LB= df['LB'].mean()

# %%
mean_of_AC= df['AC'].mean()

# %%
mean_of_DS= df['DS'].mean()

# %%
mean_of_DP= df['DP'].mean()

# %%
mean_of_MLTV= df['MLTV'].mean()

# %%
mean_of_Width= df['Width'].mean()

# %%
mean_of_Tendency= df['Tendency'].mean()

# %%
mean_of_NSP= df['NSP'].mean()

# %%
df['LB'].fillna(value=mean_of_LB,inplace=True)
# Out:
# C:\Users\andeb\AppData\Local\Temp\ipykernel_18220\2255887071.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LB'].fillna(value=mean_of_LB,inplace=True)

# %%
df['AC'].fillna(value=mean_of_AC,inplace=True)
# Out:
# C:\Users\andeb\AppData\Local\Temp\ipykernel_18220\1661742467.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AC'].fillna(value=mean_of_AC,inplace=True)

# %%
df['DS'].fillna(value=mean_of_DS,inplace=True)
# Out:
# C:\Users\andeb\AppData\Local\Temp\ipykernel_18220\803860390.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DS'].fillna(value=mean_of_DS,inplace=True)

# %%
df['DP'].fillna(value=mean_of_DP,inplace=True)
# Out:
# C:\Users\andeb\AppData\Local\Temp\ipykernel_18220\2547518048.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DP'].fillna(value=mean_of_DP,inplace=True)

# %%
df['MLTV'].fillna(value=mean_of_MLTV,inplace=True)
# Out:
# C:\Users\andeb\AppData\Local\Temp\ipykernel_18220\3676865872.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['MLTV'].fillna(value=mean_of_MLTV,inplace=True)

# %%
df['Width'].fillna(value=mean_of_Width,inplace=True)
# Out:
# C:\Users\andeb\AppData\Local\Temp\ipykernel_18220\2788971073.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Width'].fillna(value=mean_of_Width,inplace=True)

# %%
df['Tendency'].fillna(value=mean_of_Tendency,inplace=True)
# Out:
# C:\Users\andeb\AppData\Local\Temp\ipykernel_18220\1186053765.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Tendency'].fillna(value=mean_of_Tendency,inplace=True)

# %%
df['NSP'].fillna(value=mean_of_NSP,inplace=True)
# Out:
# C:\Users\andeb\AppData\Local\Temp\ipykernel_18220\1933859099.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['NSP'].fillna(value=mean_of_NSP,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2126 non-null   float64
#  1   AC        2126 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2126 non-null   float64
#  6   DP        2126 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2126 non-null   float64
#  11  Width     2126 non-null   float64
#  12  Tendency  2126 non-null   float64
#  13  NSP       2126 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
#●	Identify and correct any inconsistencies in data types (e.g., numerical values stored as strings).

# %%
#In given data all values are numerical values i.e float values there are no strings.

# %%
#●	Detect and treat outliers if necessary

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df['LB'],vert=False)
plt.show()

# %%
import numpy as np
q1=np.percentile(df['LB'],25)
q2=np.percentile(df['LB'],50)
q3=np.percentile(df['LB'],75)
iqr=q3-q1
uw=q3+(1.5*iqr)
lw=q1-(1.5*iqr)
iqr
# Out:
# np.float64(14.0)

# %%
len(df[df['LB']>uw])
# Out:
# 6

# %%
len(df[df['LB']<lw])
# Out:
# 4

# %%
df[df['LB']<lw]=lw

# %%
plt.boxplot(df['LB'],vert=False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['AC'],vert=False)
plt.show()

# %%
df['AC'].describe()
# Out:
# count    2126.000000
# mean        0.200767
# std         4.551115
# min        -0.019284
# 25%         0.000000
# 50%         0.001688
# 75%         0.005631
# max       105.000000
# Name: AC, dtype: float64

# %%
import numpy as np
q1=np.percentile(df['AC'],25)
q2=np.percentile(df['AC'],50)
q3=np.percentile(df['AC'],75)
iqr= q3-q1
uw= q3+(iqr*1.5)
lw= q1-(iqr*1.5)
iqr
# Out:
# np.float64(0.0056314265)

# %%
len(df[df['AC']>uw])
# Out:
# 40

# %%
len(df[df['AC']<lw])
# Out:
# 4

# %%
df[df['AC']>uw]=uw
df[df['AC']<lw]=lw

# %%
plt.boxplot(df['AC'],vert=False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['FM'],vert=False)
plt.show()

# %%
import numpy as np
q1=np.percentile(df['FM'],25)
q2=np.percentile(df['FM'],50)
q3=np.percentile(df['FM'],75)
iqr= q3-q1
uw= q3+(iqr*1.5)
lw= q1-(iqr*1.5)

# %%
len(df[df['FM']>uw])
# Out:
# 343

# %%
len(df[df['FM']<lw])
# Out:
# 11

# %%
df[df['FM']>uw]=uw

# %%
df[df['FM']<lw]=lw

# %%
plt.boxplot(df['FM'],vert=False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['UC'],vert=False)
plt.show()

# %%
import numpy as np
q1=np.percentile(df['UC'],25)
q2=np.percentile(df['UC'],50)
q3=np.percentile(df['UC'],75)
iqr= q3-q1
uw= q3+(iqr*1.5)
lw= q1-(iqr*1.5)

# %%
len(df[df['UC']>uw])
# Out:
# 8

# %%
len(df[df['UC']<lw])
# Out:
# 15

# %%
df[df['UC']>uw]=uw

# %%
df[df['UC']<lw]=lw

# %%
plt.boxplot(df['UC'],vert=False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['DL'],vert=False)
plt.show()

# %%
import numpy as np
q1=np.percentile(df['DL'],25)
q2=np.percentile(df['DL'],50)
q3=np.percentile(df['DL'],75)
iqr= q3-q1
uw= q3+(iqr*1.5)
lw= q1-(iqr*1.5)

# %%
len(df[df['DL']>uw])
# Out:
# 2

# %%
len(df[df['DL']<lw])
# Out:
# 6

# %%
df[df['DL']>uw]=uw

# %%
df[df['DL']<lw]=lw

# %%
plt.boxplot(df['DL'],vert=False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['DS'],vert=False)
plt.show()

# %%
import numpy as np
q1=np.percentile(df['DS'],25)
q2=np.percentile(df['DS'],50)
q3=np.percentile(df['DS'],75)
iqr= q3-q1
uw= q3+(iqr*1.5)
lw= q1-(iqr*1.5)
iqr
# Out:
# np.float64(0.0)

# %%
len(df[df['DS']>uw])
# Out:
# 429

# %%
len(df[df['DS']<lw])
# Out:
# 65

# %%
df[df['DS']>uw]=uw
df[df['DS']<lw]=lw

# %%
plt.boxplot(df['DS'],vert=False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['DP'],vert=False)
plt.show()

# %%
import numpy as np
q1=np.percentile(df['DP'],25)
q2=np.percentile(df['DP'],50)
q3=np.percentile(df['DP'],75)
iqr= q3-q1
uw= q3+(iqr*1.5)
lw= q1-(iqr*1.5)

# %%
len(df[df['DP']>uw])
# Out:
# 165

# %%
len(df[df['DP']<lw])
# Out:
# 41

# %%
df[df['DP']>uw]=uw
df[df['DP']<lw]=lw

# %%
plt.boxplot(df['DP'],vert=False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['ASTV'],vert=False)
plt.show()

# %%
import numpy as np
q1=np.percentile(df['ASTV'],25)
q2=np.percentile(df['ASTV'],50)
q3=np.percentile(df['ASTV'],75)
iqr= q3-q1
uw= q3+(iqr*1.5)
lw= q1-(iqr*1.5)

# %%
len(df[df['ASTV']>uw])
# Out:
# 5

# %%
len(df[df['ASTV']<lw])
# Out:
# 0

# %%
df[df['ASTV']>uw]=uw
df[df['ASTV']<lw]=lw

# %%
plt.boxplot(df['ASTV'],vert=False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['MSTV'],vert=False)
plt.show()

# %%
import numpy as np
q1=np.percentile(df['MSTV'],25)
q2=np.percentile(df['MSTV'],50)
q3=np.percentile(df['MSTV'],75)
iqr= q3-q1
uw= q3+(iqr*1.5)
lw= q1-(iqr*1.5)

# %%
len(df[df['MSTV']>uw])
# Out:
# 43

# %%
len(df[df['MSTV']<lw])
# Out:
# 2

# %%
df[df['MSTV']>uw]=uw
df[df['MSTV']<lw]=lw

# %%
plt.boxplot(df['MSTV'],vert=False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['ALTV'],vert=False)
plt.show()

# %%
import numpy as np
q1=np.percentile(df['ALTV'],25)
q2=np.percentile(df['ALTV'],50)
q3=np.percentile(df['ALTV'],75)
iqr= q3-q1
uw= q3+(iqr*1.5)
lw= q1-(iqr*1.5)

# %%
len(df[df['ALTV']>uw])
# Out:
# 370

# %%
len(df[df['ALTV']<lw])
# Out:
# 2

# %%
df[df['ALTV']>uw]=uw
df[df['ALTV']<lw]=lw

# %%
plt.boxplot(df['ALTV'],vert=False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['MLTV'],vert=False)
plt.show()

# %%
import numpy as np
q1=np.percentile(df['MLTV'],25)
q2=np.percentile(df['MLTV'],50)
q3=np.percentile(df['MLTV'],75)
iqr= q3-q1
uw= q3+(iqr*1.5)
lw= q1-(iqr*1.5)

# %%
len(df[df['MLTV']>uw])
# Out:
# 5

# %%
len(df[df['MLTV']<lw])
# Out:
# 1

# %%
df[df['MLTV']>uw]=uw
df[df['MLTV']<lw]=lw

# %%
plt.boxplot(df['MLTV'],vert=False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['Width'],vert=False)
plt.show()

# %%
import numpy as np
q1=np.percentile(df['Width'],25)
q2=np.percentile(df['Width'],50)
q3=np.percentile(df['Width'],75)
iqr= q3-q1
uw= q3+(iqr*1.5)
lw= q1-(iqr*1.5)

# %%
len(df[df['Width']>uw])
# Out:
# 7

# %%
len(df[df['Width']<lw])
# Out:
# 3

# %%
df[df['Width']>uw]=uw
df[df['Width']<lw]=lw

# %%
plt.boxplot(df['Width'],vert=False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['Tendency'],vert=False)
plt.show()

# %%
import numpy as np
q1=np.percentile(df['Tendency'],25)
q2=np.percentile(df['Tendency'],50)
q3=np.percentile(df['Tendency'],75)
iqr= q3-q1
uw= q3+(iqr*1.5)
lw= q1-(iqr*1.5)

# %%
len(df[df['Tendency']>uw])
# Out:
# 427

# %%
len(df[df['Tendency']<lw])
# Out:
# 10

# %%
df[df['Tendency']>uw]=uw
df[df['Tendency']<lw]=lw

# %%
plt.boxplot(df['Tendency'],vert=False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['NSP'],vert=False)
plt.show()

# %%
import numpy as np
q1=np.percentile(df['NSP'],25)
q2=np.percentile(df['NSP'],50)
q3=np.percentile(df['NSP'],75)
iqr= q3-q1
uw= q3+(iqr*1.5)
lw= q1-(iqr*1.5)

# %%
len(df[df['NSP']>uw])
# Out:
# 11

# %%
len(df[df['NSP']<lw])
# Out:
# 0

# %%
df[df['NSP']>uw]=uw
df[df['NSP']<lw]=lw

# %%
plt.boxplot(df['NSP'],vert=False)
plt.show()

# %%
# Here all the outliers are detected and removed in all variables

# %%
#2.	Statistical Summary:
#●	Provide a statistical summary for each variable in the dataset, including measures of central tendency (mean, median) and dispersion (standard deviation, interquartile range).

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean     61.492564     0.509835     0.508320     0.510237     0.508851
# std      66.016978     1.019207     1.019958     1.019006     1.019695
# min      -1.500000    -1.500000    -1.500000    -1.500000    -1.500000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       2.500000     0.001582     0.000000     0.003920     0.000000
# 75%     132.000000     0.009863     0.003196     0.008373     0.006098
# max     214.000000     2.500000     2.500000     2.500000     2.500000
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.507996     0.507996    19.813646     1.124939     1.266318
# std       1.020119     1.020119    23.173953     1.010342     2.350871
# ...

# %%
# Above are the mean,standard deviation and interquartile range values of all variables in the data set

# %%
df.median()
# Out:
# LB          2.500000
# AC          0.001582
# FM          0.000000
# UC          0.003920
# DL          0.000000
# DS          0.000000
# DP          0.000000
# ASTV        2.500000
# MSTV        1.100000
# ALTV        0.000000
# MLTV        2.500000
# Width       2.500000
# Tendency    0.000000
# NSP         1.000000
# dtype: float64

# %%
# These are median values of all variables in the given data set

# %%
#●	Highlight any interesting findings from this summary

# %%
import numpy as np
q1=np.percentile(df['LB'],25)
q2=np.percentile(df['LB'],50)
q3=np.percentile(df['LB'],75)
iqr=q3-q1
iqr
# Out:
# np.float64(132.0)

# %% [markdown]
# ## """
# For LB, the mean(61.492564) is greater than median(2.500000) the data is positively skewed,
# the standard deviation(66.016978) is slightly lower which indicates the values not widely spread from the mean value,
# the interquartile range(132) is a large iqr value,i.e the 50% of the data is widely spread.
# """

# %%
import numpy as np
q1=np.percentile(df['AC'],25)
q2=np.percentile(df['AC'],50)
q3=np.percentile(df['AC'],75)
iqr=q3-q1
iqr
# Out:
# np.float64(0.0098630225)

# %%
#For AC, the mean(0.509835) is greater than median(0.001582) the data is positively skewed,
#the standard deviation(1.019207) is slightly higer which indicates the values are spread from the mean value,
#the interquartile range(0.0098630225) is a small iqr value,i.e the 50% of the data is tightly closed.

# %%
import numpy as np
q1=np.percentile(df['FM'],25)
q2=np.percentile(df['FM'],50)
q3=np.percentile(df['FM'],75)
iqr=q3-q1
iqr
# Out:
# np.float64(0.003195745)

# %%
## """
#For FM, the mean(0.508320) is greater than median(0.000000) the data is positively skewed,
#the standard deviation(1.019958) is slightly higer which indicates the values are spread from the mean value,
#the interquartile range(0.003195745) is a very small iqr value,i.e the 50% of the data is tightly closed.

# %%
import numpy as np
q1=np.percentile(df['UC'],25)
q2=np.percentile(df['UC'],50)
q3=np.percentile(df['UC'],75)
iqr=q3-q1
iqr
# Out:
# np.float64(0.00837302325)

# %%
## """
#For UC, the mean(0.510237) is greater than median(0.003920) the data is positively skewed,
#the standard deviation(1.019006	) is slightly higher which indicates the values are spread from the mean value,
#the interquartile range(0.00837302325) is a very small iqr value,i.e the 50% of the data is tightly closed

# %%
import numpy as np
q1=np.percentile(df['DL'],25)
q2=np.percentile(df['DL'],50)
q3=np.percentile(df['DL'],75)
iqr=q3-q1
iqr
# Out:
# np.float64(0.006097561)

# %%
## """
#For DL, the mean(0.508851) is greater than median(0.000000) the data is positively skewed,
#the standard deviation(1.019695	) is slightly higher which indicates the values are spread from the mean value,
#the interquartile range(0.006097561) is a very small iqr value,i.e the 50% of the data is tightly closed.

# %%
import numpy as np
q1=np.percentile(df['DS'],25)
q2=np.percentile(df['DS'],50)
q3=np.percentile(df['DS'],75)
iqr=q3-q1
iqr
# Out:
# np.float64(0.0)

# %%
## """
#For DS, the mean(0.507996) is greater than median(0.000000) the data is positively skewed,
#the standard deviation(1.020119	) is slightly higher which indicates the values are spread from the mean value,
#the interquartile range(0.0) is a very small iqr value,i.e all the data lies outside the box.

# %%
import numpy as np
q1=np.percentile(df['DP'],25)
q2=np.percentile(df['DP'],50)
q3=np.percentile(df['DP'],75)
iqr=q3-q1
iqr
# Out:
# np.float64(0.0)

# %%
## """
#For DP, the mean(0.507996) is greater than median(0.000000) the data is positively skewed,
#the standard deviation(1.020119) is slightly higher which indicates the values are spread from the mean value,
#the interquartile range(0.0) is a very small iqr value,i.e all the data lies outside the box.

# %%
import numpy as np
q1=np.percentile(df['ASTV'],25)
q2=np.percentile(df['ASTV'],50)
q3=np.percentile(df['ASTV'],75)
iqr=q3-q1
iqr
# Out:
# np.float64(38.84878517241433)

# %%
## """
#For ASTV, the mean(19.813646) is greater than median(2.500000) the data is positively skewed,
#the standard deviation(23.173953) is slightly higher which indicates the values are spread from the mean value,
#the interquartile range(38.84878517241433) is a large iqr value,i.e the 50% of the data is widely spread

# %%
import numpy as np
q1=np.percentile(df['MSTV'],25)
q2=np.percentile(df['MSTV'],50)
q3=np.percentile(df['MSTV'],75)
iqr=q3-q1
iqr
# Out:
# np.float64(2.2)

# %%
## """
#For MSTV, the mean(1.124939	) is slightly greater than median(1.100000) the data is positively skewed,
#the standard deviation(1.010342	) is slightly higher which indicates the values are not much spread from the mean value,
#the interquartile range(2.2) is a  small iqr value,i.e all the data is closely packed.

# %%
import numpy as np
q1=np.percentile(df['ALTV'],25)
q2=np.percentile(df['ALTV'],50)
q3=np.percentile(df['ALTV'],75)
iqr=q3-q1
iqr
# Out:
# np.float64(2.5)

# %%
## """
#For ALTV, the mean(1.266318	) is greater than median(0.000000) the data is positively skewed,
#the standard deviation(2.350871) is slightly higher which indicates the values are spread from the mean value,
#the interquartile range(0.0) is a very small iqr value,i.e all the data lies outside the box.

# %%
import numpy as np
q1=np.percentile(df['MLTV'],25)
q2=np.percentile(df['MLTV'],50)
q3=np.percentile(df['MLTV'],75)
iqr=q3-q1
iqr
# Out:
# np.float64(8.2)

# %%
## """
#For MLTV, the mean(4.709440	) is greater than median(2.500000) the data is positively skewed,
#the standard deviation(2.350871	) is slightly higher which indicates the values are spread from the mean value,
#the interquartile range(8.2) is a small iqr value,i.e all the data is closely packed.

# %%
import numpy as np
q1=np.percentile(df['Width'],25)
q2=np.percentile(df['Width'],50)
q3=np.percentile(df['Width'],75)
iqr=q3-q1
iqr
# Out:
# np.float64(61.0)

# %%
## """
#For Width, the mean(32.80352	) is greater than median(2.500000) the data is positively skewed,
#the standard deviation(40.58913) is slightly higher which indicates the values are spread from the mean value,
#the interquartile range(61.0) is a more iqr value,i.e all the 50% data spreads over the box.

# %%
import numpy as np
q1=np.percentile(df['Tendency'],25)
q2=np.percentile(df['Tendency'],50)
q3=np.percentile(df['Tendency'],75)
iqr=q3-q1
iqr
# Out:
# np.float64(1.0)

# %%
## """
#For Tendency, the mean(0.679203) is greater than median(0.000000) the data is positively skewed,
#the standard deviation(1.028827) is slightly higher which indicates the values are spread from the mean value,
#the interquartile range(1.0) is a small iqr value,i.e all the 50% data closely packed.

# %%
import numpy as np
q1=np.percentile(df['NSP'],25)
q2=np.percentile(df['NSP'],50)
q3=np.percentile(df['NSP'],75)
iqr=q3-q1
iqr
# Out:
# np.float64(1.0)

# %%
## """
#For NSP, the mean(0.989143) is lesser than median(1.000000) the data is negativelyskewed,
#the standard deviation(0.923110) is slightly higher which indicates the values are spread from the mean value,
#the interquartile range(1.0) is a very small iqr value,i.e all the 50% data closely packed.

# %%
#4.	Pattern Recognition and Insights:

# %%
#●	Identify any correlations between variables and discuss their potential implications.

# %%
df.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.443225 -0.444509 -0.442910 -0.444079 -0.444781
# AC       -0.443225  1.000000  0.999995  0.999995  0.999994  0.999995
# FM       -0.444509  0.999995  1.000000  0.999996  0.999998  0.999999
# UC       -0.442910  0.999995  0.999996  1.000000  0.999996  0.999996
# DL       -0.444079  0.999994  0.999998  0.999996  1.000000  0.999998
# DS       -0.444781  0.999995  0.999999  0.999996  0.999998  1.000000
# DP       -0.444781  0.999995  0.999999  0.999996  0.999998  1.000000
# ASTV      0.890438 -0.369637 -0.370613 -0.369361 -0.370380 -0.371028
# MSTV      0.199208  0.706575  0.705668  0.706788  0.706323  0.705455
# ALTV      0.167806  0.273063  0.273250  0.273645  0.273128  0.273224
# MLTV      0.727183 -0.191234 -0.191753 -0.190546 -0.191669 -0.191908
# Width     0.847688 -0.369609 -0.370931 -0.369676 -0.370212 -0.371279
# Tendency -0.251142  0.908862  0.908698  0.908937  0.908912  0.908628
# ...

# %%
# good postive relationship means having correlation value above 0.5 to 1
#good negative relationship means having correlation value above -0.5 to -1

# %%
#LB variable is having good postive relationship with ASTV,MLTV,Width variables 
#and negative relationship with LB,AC,FM,UC,DL,DS,DP

# %%
#AC variable is having good postive relationship with FM,UC,DL,DS,DP,MSTV,Tendency,NSP variables 
#and good negative relationship with MLTV,Width

# %%
#FM variable is having good postive relationship with AC,UC,DL,DS,DP,MSTV,Tendency,NSP variables 
#and good negative relationship with LB,ASTV,MLTV,Width

# %%
#UC variable is having good postive relationship with AC,FM,DL,DS,DP,MSTV,Tendency,NSP variables 
#and good negative relationship with LB,ASTV,MLTV,Width

# %%
#DL variable is having good postive relationship with AC,FM,UC,DS,DP,MSTV,Tendency,NSP variables 
#and good negative relationship with LB,ASTV,MLTV,Width

# %%
#DS variable is having good postive relationship with AC,FM,UC,DL,DP,MSTV,Tendency,NSP variables 
#and good negative relationship with LB,ASTV,MLTV,Width

# %%
#DP variable is having good postive relationship with AC,FM,UC,DS,DL,MSTV,Tendency,NSP variables 
#and good negative relationship with LB,ASTV,MLTV,Width

# %%
#ASTV variable is having good postive relationship with LB,MLTV,Width variables 
#and good negative relationship with AC,FM,UC,DL,DS,DP,Tendency

# %%
#MSTV variable is having good postive relationship with AC,FM,UC,Dl,DS,DP,Tendency,NSP variables 
#and there is no negative relationship with other variables

# %%
#AlTV variable is having poor postive relationship with all variables in the data set

# %%
#MlTV variable is having good postive relationship with LB,ASTV,Width variables 
#and good negative relationship with AC,FM,UC,DL,DS,DP,Tendency,NSP

# %%
#Width variable is having good postive relationship with LB,MLTV,ASTV variables 
#and good negative relationship with AC,FM,UC,DL,DS,DP,Tendency

# %%
#Tendency variable is having good postive relationship with AC,FM,UC,DL,DS,DP,MSTV,NSP variables 
#and good negative relationship with LB,ASTV,MLTV,Width

# %%
#NSP variable is having good postive relationship with AC,FM,UC,DL,DS,DP,MSTV,Tendency variables 
#and there is no good negative relationship with other variables in the data set.

# %%
#●	Look for trends or patterns over time if temporal data is available.

# %%
# here AC,FM,UC,DL,DS,DP,MSTV,Tendency,NLP, these variables are highly positively correlated with each other if one increases other increases if one decreases other also decreases

# %%
#LB,ASTV,MLTV are highly correlated with each other, i.e one variable is higly influenced by other

# %%
#ALTV is influenced by all other variables in the data set.

# %%
#3.	Data Visualization:

# %%
#●	Create histograms or boxplots to visualize the distributions of various numerical variables.

# %%
df
# Out:
#               LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  \
# 0       2.500000  2.500000  2.5  2.500000  2.500000  2.5  2.5   2.5   2.5
# 1     132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1
# 2     133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1
# 3     134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4
# 4     131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4
# ...          ...       ...  ...       ...       ...  ...  ...   ...   ...
# 2121    0.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0   0.0   0.0
# 2122    2.500000  2.500000  2.5  2.500000  2.500000  2.5  2.5   2.5   2.5
# 2123    2.500000  2.500000  2.5  2.500000  2.500000  2.5  2.5   2.5   2.5
# 2124    2.500000  2.500000  2.5  2.500000  2.500000  2.5  2.5   2.5   2.5
# 2125    2.500000  2.500000  2.5  2.500000  2.500000  2.5  2.5   2.5   2.5
#
#       ALTV  MLTV  Width  Tendency  NSP
# 0      2.5   2.5    2.5       2.5  2.5
# ...

# %%
df['LB'].hist()
# Out:
# <Axes: >

# %%
df['AC'].hist()
# Out:
# <Axes: >

# %%
df['FM'].hist()
# Out:
# <Axes: >

# %%
df['UC'].hist()
# Out:
# <Axes: >

# %%
df['DL'].hist()
# Out:
# <Axes: >

# %%
df['DS'].hist()
# Out:
# <Axes: >

# %%
df['DP'].hist()
# Out:
# <Axes: >

# %%
df['ASTV'].hist()
# Out:
# <Axes: >

# %%
df['MSTV'].hist()
# Out:
# <Axes: >

# %%
df['ALTV'].hist()
# Out:
# <Axes: >

# %%
df['MLTV'].hist()
# Out:
# <Axes: >

# %%
df['Width'].hist()
# Out:
# <Axes: >

# %%
df['Tendency'].hist()
# Out:
# <Axes: >

# %%
df['NSP'].hist()
# Out:
# <Axes: >

# %%
#●	Use bar charts or pie charts to display the frequency of categories for categorical variables.

# %%
#There are no categorial variables in the given data set all variables are continuous variables.

# %%
#●	Generate scatter plots or correlation heatmaps to explore relationships between pairs of variables.

# %%
import matplotlib.pyplot as plt
plt.scatter(df['AC'],df['FM'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['AC'],df['UC'],color='green')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['AC'],df['DL'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['AC'],df['DS'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['AC'],df['DP'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['AC'],df['MSTV'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['AC'],df['Tendency'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['AC'],df['NSP'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['AC'],df['LB'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['AC'],df['ASTV'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['AC'],df['MLTV'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['AC'],df['ALTV'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['ASTV'],df['MLTV'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['MLTV'],df['ALTV'])
plt.show()

# %%
## here AC,FM,UC,DL,DS,DP,MSTV,Tendency,NSP, these variables are highly positively correlated with each other if one increases other increases if one decreases other also decreases

# %%
#LB,ASTV,MSTV are highly correlated with each other, i.e one variable is higly influenced by other

# %%
#ALTV is influenced by all other variables in the data set.

# %%
#●	Employ advanced visualization techniques like pair plots, or violin plots for deeper insights.

# %%
#Creating pair plots for all variables

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df,hue='NSP')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.violinplot(x='LB',y='NSP',data=df)
plt.show()

# %%
#5.	Conclusion:
#●	Summarize the key insights and patterns discovered through your exploratory analysis.
#●	Discuss how these findings could impact decision-making or further analyses.

# %%
# Here in this data set, our target variable is NSP. The variables AC,FM,UC,DL,DS,DP,MSTV,Tendency are higly correlated with our target variable.
# These variables can be used for model tunning.These variables are mostly effecting our target variable and as these variable value increases our target value increases.
#But we want our target variable to get less value so these variables should be less.
