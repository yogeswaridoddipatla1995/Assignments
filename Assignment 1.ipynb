# %%
#Coding Exercises

# %%
#Exercise 1: Prime Numbers
Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
def is_prime(n):
    if n>=1:
        return False
    if n==2:
        return True
    if n/2==0:
        return False
    for i in range(3,(n**0.5)+1,2):
        if n%2==0:
            return False
        return True

# %%
num= int(input("Give a number: "))
if is_prime(num):
    print("num is a prime number")
else:
    print("num is not a prime number")
# Out:
# Give a number:  5
# num is not a prime number

# %%
#Exercise 2: Product of Random Numbers
Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import numpy as np

# %%
(a,b)= np.random.randint(10,20,size=2)

# %%
a
# Out:
# np.int32(11)

# %%
b
# Out:
# np.int32(12)

# %%
product= int(input("Enter the product of a and b: "))
# Out:
# Enter the product of a and b:  190

# %%
if product==a*b:
    print("The user is right")
else:
    print("The user is wrong")
# Out:
# The user is wrong

# %%
#Exercise 3: Squares of Even/Odd Numbers
Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
for num in range(100,201):
    if num%2==0:
        square= num**2
        print("num^2= ",square)
# Out:
# num^2=  10000
# num^2=  10404
# num^2=  10816
# num^2=  11236
# num^2=  11664
# num^2=  12100
# num^2=  12544
# num^2=  12996
# num^2=  13456
# num^2=  13924
# num^2=  14400
# num^2=  14884
# num^2=  15376
# num^2=  15876
# num^2=  16384
# num^2=  16900
# num^2=  17424
# num^2=  17956
# num^2=  18496
# num^2=  19044
# num^2=  19600
# num^2=  20164
# num^2=  20736
# num^2=  21316
# num^2=  21904
# num^2=  22500
# num^2=  23104
# num^2=  23716
# num^2=  24336
# num^2=  24964
# num^2=  25600
# num^2=  26244
# num^2=  26896
# num^2=  27556
# num^2=  28224
# num^2=  28900
# num^2=  29584
# num^2=  30276
# num^2=  30976
# num^2=  31684
# num^2=  32400
# num^2=  33124
# num^2=  33856
# num^2=  34596
# num^2=  35344
# num^2=  36100
# num^2=  36864
# num^2=  37636
# num^2=  38416
# num^2=  39204
# num^2=  40000

# %%
#Exercise 4:
"""
✅ Problem Statement (Question): Hospital Billing System
A hospital charges its patients based on the following:
•	Room charges per day: ₹2,000
•	Doctor consultation fee (flat): ₹1,500
•	Lab test charges: Based on the number of tests taken. Each test costs ₹300
•	Medicine charges: Total cost of medicines provided
•	Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
Write a Python program to calculate the final bill for a patient who:
•	Stayed for 4 days
•	Had 3 lab tests
•	Had medicine charges of ₹2,400

"""
# Out:
# '\n✅ Problem Statement (Question): Hospital Billing System\nA hospital charges its patients based on the following:\n•\tRoom charges per day: ₹2,000\n•\tDoctor consultation fee (flat): ₹1,500\n•\tLab test charges: Based on the number of tests taken. Each test costs ₹300\n•\tMedicine charges: Total cost of medicines provided\n•\tDiscount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied\nWrite a Python program to calculate the final bill for a patient who:\n•\tStayed for 4 days\n•\tHad 3 lab tests\n•\tHad medicine charges of ₹2,400\n\n'

# %%
# Hospital Billing System

# %%
Room_charges_per_day= 2000
Doctor_consultation_fee = 1500
Lab_test_charges_per_test= 300
Discount=0.1
Discount_aligibility_amount=10000
#patient details
days_stayed=4
tests_counducted=3
Medical_charges = 2400

# %%
Room_charges=Room_charges_per_day*days_stayed
Test_charges=Lab_test_charges_per_test*tests_counducted

# %%
Total_bill= Room_charges+Test_charges+Medical_charges+Doctor_consultation_fee

# %%
Total_bill
# Out:
# 12800

# %%
print("Hospital Bills")
print("Doctor consultation fee =",Doctor_consultation_fee)
print("Room charges =",Room_charges)
print("Lab test charges = ",Test_charges)
print("Medicine charges=",Medical_charges)
print("Total bill= ",Total_bill)
if Total_bill>10000:
    discount=Total_bill*0.1
    td =discount+Total_bill
    print("Total_bill with discount is: ",td)
else:
    print("Total_bill without discount is:",Total_bill)
# Out:
# Hospital Bills
# Doctor consultation fee = 1500
# Room charges = 8000
# Lab test charges =  900
# Medicine charges= 2400
# Total bill=  12800
# Total_bill with discount is:  14080.0
